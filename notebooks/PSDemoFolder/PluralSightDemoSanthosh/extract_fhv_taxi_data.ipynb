# %%
from pyspark.sql.functions import *
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
#dbutils.fs.ls('/mnt/storage/')
#dbutils.fs.ls('/mnt/storage/')
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
#dbutils.fs.unmount('/mnt/storage')
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
#dbutils.fs.ls('mnt/datalake/')
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
fhv_trips_df = spark.read \
                .option('header', 'true') \
                .option('inferSchema', 'true') \
                .csv('/mnt/storage/fhv_tripdata_2018-12.csv')
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
display(fhv_trips_df.describe("Pickup_DateTime"))
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>summary</th><th>Pickup_DateTime</th></tr></thead><tbody><tr><td>count</td><td>23854144</td></tr><tr><td>mean</td><td>null</td></tr><tr><td>stddev</td><td>null</td></tr><tr><td>min</td><td>2018-12-01 00:00:00</td></tr><tr><td>max</td><td>2018-12-31 23:59:59</td></tr></tbody></table></div>

# %%
'''display(
    fhv_trips_df.describe()
)'''
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[59]: &#39;display(\n    fhv_trips_df.describe()\n)&#39;</div>

# %%
#print('before = ', fhv_trips_df.count())

fhv_trips_df = fhv_trips_df \
                .na.drop(how='any',subset=('PUlocationID', 'DOlocationID')) \
                .drop_duplicates() \
                .where( (col("Pickup_DateTime") > '2018-11-31') & (col('DropOff_datetime') < '2019-01-01') )

#print('after = ', fhv_trips_df.count())
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
fhv_trips_df = fhv_trips_df.select( \
                                  'Pickup_DateTime',
                                  'DropOff_datetime',
                                  'PUlocationID',
                                  'DOlocationID',
                                  'SR_Flag',
                                  'Dispatching_base_number'
                                  )

# We could have also dropped a col using fhv_trips_df = fhv_trips_df.drop('Dispatching_base_num')
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
fhv_trips_df = fhv_trips_df.select( \
                                  col('Pickup_DateTime').alias('pickup_date_time'),
                                  col('DropOff_datetime').alias('dropoff_date_time'),
                                  col('PUlocationID').alias('pickup_location'),
                                  col('DOlocationID').alias('dropoff_location'),
                                  col('SR_Flag').alias('sr_flag'),
                                  col('Dispatching_base_number').alias('dispatching_base_number')
                           )

'''
other way to rename columns
fhvTaxiTripDataDF = fhvTaxiTripDataDF
                        .withColumnRenamed("DropOff_DateTime", "DropTime")
                        .withColumnRenamed("PUlocationID", "PickupLocationId")
                        .withColumnRenamed("DOlocationID", "DropLocationId")
                        .withColumnRenamed("Dispatching_base_number", "BaseLicenseNumber")
'''
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[62]: &#39;\nother way to rename columns\nfhvTaxiTripDataDF = fhvTaxiTripDataDF\n                        .withColumnRenamed(&#34;DropOff_DateTime&#34;, &#34;DropTime&#34;)\n                        .withColumnRenamed(&#34;PUlocationID&#34;, &#34;PickupLocationId&#34;)\n                        .withColumnRenamed(&#34;DOlocationID&#34;, &#34;DropLocationId&#34;)\n                        .withColumnRenamed(&#34;Dispatching_base_number&#34;, &#34;BaseLicenseNumber&#34;)\n&#39;</div>

# %%
fhv_trips_df = fhv_trips_df \
                .withColumn('pickup_year', year('pickup_date_time')) \
                .withColumn('pickup_month', month('pickup_date_time')) \
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
fhv_trips_df = fhv_trips_df.select(
                                    '*',
                                     dayofmonth('pickup_date_time').alias('pickup_day')
)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
#display(fhv_trips_df.describe('sr_flag'))
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
'''
display(
    fhv_trips_df.select(
        'Pickup_DateTime',
        'DropOff_datetime',
        round((unix_timestamp('DropOff_datetime') - unix_timestamp('Pickup_DateTime')) / 60).alias('trip_duration')
    )
)
'''
# need to be careful about open close brackets. Had initially forgotten to add a (). round(unix_timestamp('dropoff_date_time') - unix_timestamp('pickup_date_time') / 60).alias('trip_duration')
# What happens in the above line is that, only the pickup time unix timestamp is divided by 60 "unix_timestamp('pickup_date_time') / 60" and is subtracted by the drop_off_time
fhv_trips_df = fhv_trips_df.select(
                                    '*',
                                    round((unix_timestamp('dropoff_date_time') - unix_timestamp('pickup_date_time')) / 60).alias('trip_duration')
)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
fhv_trips_df = fhv_trips_df.withColumn('trip_type',
                                       when(col('sr_flag') == 1, 'shared_trip') \
                                       .when(col('sr_flag') == 0, 'solo_trip') \
                                       .otherwise('solo_trip')
                                      ) \
                            .drop('sr_flag')
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
#display(fhv_trips_df.describe('trip_type'))
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
# %fs ls /mnt/storage
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>path</th><th>name</th><th>size</th></tr></thead><tbody><tr><td>dbfs:/mnt/storage/FhvBases.json</td><td>FhvBases.json</td><td>464836</td></tr></tbody></table></div>

# %%
fhvbases_df = spark.read \
                    .option("inferSchema", "true") \
                    .option("multiline", "true") \
                    .json("/mnt/storage/FhvBases.json")
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
#dbutils.fs.head('/mnt/storage/FhvBases.json')
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
fhv_bases_df = spark.read \
                .option('inferSchema', 'true') \
                .option('multiline', 'true') \
                .json('/mnt/storage/FhvBases.json')
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
'''
display(fhv_bases_df)
display(fhv_bases_df.head(5))
display(fhv_bases_df.describe())
display(fhv_bases_df.describe('Telephone Number'))
'''
#display(fhv_bases_df.head(5))
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[72]: &#34;\ndisplay(fhv_bases_df)\ndisplay(fhv_bases_df.head(5))\ndisplay(fhv_bases_df.describe())\ndisplay(fhv_bases_df.describe(&#39;Telephone Number&#39;))\n&#34;</div>

# %%
fhv_bases_df = fhv_bases_df.select(
                    col('License Number').alias('base_liscence_number'),
                    col('Type of Base').alias('base_type'),
    
                    col('Address.Building').alias('building_name'),
                    col('Address.Street').alias('street'),
                    col('Address.City').alias('city'),
                    col('Address.State').alias('state'),
                    col('Address.Postcode').alias('post_code'),
                    )

#display(fhv_bases_df)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
'''
For some unknown reasons, the following is not working properly

joined_df = fhv_trips_df.join(fhv_bases_df, 
                 col("fhv_trips_df.dispatching_base_number") == col("fhv_bases_df.base_liscence_number"),
                  'inner'
                 )

it should work just fine according to this documentation
https://spark.apache.org/docs/latest/api/python/pyspark.sql.html?highlight=alias (search for join in this page. you will see the following line)
# joined_df = df_as1.join(df_as2, col("df_as1.name") == col("df_as2.name"), 'inner')
'''
fhv_trips_bases_df = fhv_trips_df.join(fhv_bases_df, 
                 fhv_trips_df.dispatching_base_number == fhv_bases_df.base_liscence_number,
                  'inner'
                 )
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
#display(fhv_trips_bases_df)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
aggregated_df = fhv_trips_bases_df \
                .groupBy('city', 'base_type') \
                .sum('trip_duration') \
                \
                .withColumnRenamed('sum(trip_duration)', 'total_trip_time') \
                \
                .orderBy('city', 'base_type')

#display(aggregated_df)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %% [markdown]
# ##Fhv Taxi cleanup and transfromation (All the above transformations in single step)

# %%
fhv_trips_df = spark.read \
                .option('header', 'true') \
                .option('inferSchema', 'true') \
                .csv('/mnt/storage/fhv_tripdata_2018-12.csv')
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
fhv_trips_df = fhv_trips_df \
                \
                .na.drop(how='any',subset=('PUlocationID', 'DOlocationID')) \
                .drop_duplicates() \
                .where( (col("Pickup_DateTime") > '2018-11-31') & (col('DropOff_datetime') < '2019-01-01') ) \
                \
                .select( \
                                  col('Pickup_DateTime').alias('pickup_date_time'),
                                  col('DropOff_datetime').alias('dropoff_date_time'),
                                  col('PUlocationID').alias('pickup_location'),
                                  col('DOlocationID').alias('dropoff_location'),
                                  col('SR_Flag').alias('sr_flag'),
                                  col('Dispatching_base_number').alias('dispatching_base_number'),
                           ) \
                \
                .withColumn('pickup_year', year('pickup_date_time')) \
                .withColumn('pickup_month', month('pickup_date_time')) \
                \
                .select( \
                        '*',
                        round( \
                              (unix_timestamp('dropoff_date_time') - unix_timestamp('pickup_date_time')) / 60
                             ).alias('trip_duration'),
                        dayofmonth('pickup_date_time').alias('pickup_day')
                        ) \
                \
                .withColumn(\
                           'trip_type',
                           when(col('sr_flag') == 1, 'shared_trip') \
                           .when(col('sr_flag') == 2, 'solo_trip') \
                           .otherwise('solo_trip') \
                           ) \
                \
                .drop('sr_flag')
                
'''
# Clean and filter data
# Select only limited columns (rename if column names are not relevant)
# Create derived columns
# Create derived cols using switch case statements and drop 'sr_flag' col as its not needed anymore
'''
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[7]: &#34;\n# Clean and filter data\n# Select only limited columns (rename if column names are not relevant)\n# Create derived columns\n# Create derived cols using switch case statements and drop &#39;sr_flag&#39; col as its not needed anymore\n&#34;</div>

# %%
display(fhv_trips_df.describe())
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>summary</th><th>pickup_date_time</th><th>dropoff_date_time</th><th>pickup_location</th><th>dropoff_location</th><th>dispatching_base_number</th><th>pickup_year</th><th>pickup_month</th><th>trip_duration</th><th>pickup_day</th><th>trip_type</th></tr></thead><tbody><tr><td>count</td><td>20946339</td><td>20946339</td><td>20946339</td><td>20946339</td><td>20946339</td><td>20946339</td><td>20946339</td><td>20946339</td><td>20946339</td><td>20946339</td></tr><tr><td>mean</td><td>null</td><td>null</td><td>138.94598554907375</td><td>141.6902006598862</td><td>null</td><td>2018.0</td><td>12.0</td><td>20.50503784933491</td><td>15.407948949933447</td><td>null</td></tr><tr><td>stddev</td><td>null</td><td>null</td><td>75.36454777711155</td><td>77.83205624891409</td><td>null</td><td>0.0</td><td>0.0</td><td>15.689344112937787</td><td>8.850352057891298</td><td>null</td></tr><tr><td>min</td><td>2018-12-01 00:00:00</td><td>2018-12-01 00:02:18</td><td>0</td><td>0</td><td>B00021</td><td>2018</td><td>12</td><td>-683.0</td><td>1</td><td>shared_trip</td></tr><tr><td>max</td><td>2018-12-31 23:58:12</td><td>2018-12-31 23:59:59</td><td>265</td><td>265</td><td>B03156</td><td>2018</td><td>12</td><td>7543.0</td><td>31</td><td>solo_trip</td></tr></tbody></table></div>

# %%
fhv_trips_bases_df.createOrReplaceTempView('local_fhv_taxi_trips_data')
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
sql_based_df = spark.sql("select * from local_fhv_taxi_trips_data where base_liscence_number = 'B00021'")
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
display(sql_based_df)

# %%
# %sql

select * from local_fhv_taxi_trips_data
where base_liscence_number = 'B00021';

# %%
fhv_trips_bases_df.createOrReplaceGlobalTempView('fact_fhv_taxi_trip_data')
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
fhv_trips_bases_df.createOrReplaceGlobalTempView('fact_fhv_taxi_trip_data')
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>
