# %%
# %sh
wget -P /tmp https://s3.amazonaws.com/nyc-tlc/trip+data/yellow_tripdata_2018-12.csv
wget -P /tmp https://s3.amazonaws.com/nyc-tlc/trip+data/green_tripdata_2018-12.csv

# %%
dbutils.fs.cp("file:///tmp/yellow_tripdata_2018-12.csv", "/mnt/datalake/")
dbutils.fs.cp("file:///tmp/green_tripdata_2018-12.csv", "/mnt/datalake/")

# %%
# %fs ls /mnt/datalake/
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>path</th><th>name</th><th>size</th></tr></thead><tbody><tr><td>dbfs:/mnt/datalake/GreenTaxiTripData_201812.csv</td><td>GreenTaxiTripData_201812.csv</td><td>62056490</td></tr><tr><td>dbfs:/mnt/datalake/PaymentTypes.json</td><td>PaymentTypes.json</td><td>277</td></tr><tr><td>dbfs:/mnt/datalake/RateCodes.csv</td><td>RateCodes.csv</td><td>139</td></tr><tr><td>dbfs:/mnt/datalake/RateCodes.json</td><td>RateCodes.json</td><td>252</td></tr><tr><td>dbfs:/mnt/datalake/TaxiZones.csv</td><td>TaxiZones.csv</td><td>12322</td></tr><tr><td>dbfs:/mnt/datalake/yellow_tripdata_2018-12.csv</td><td>yellow_tripdata_2018-12.csv</td><td>721522221</td></tr></tbody></table></div>

# %%
from pyspark.sql.functions import year, month, dayofmonth, unix_timestamp, round, when, col
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
yellow_taxi_trip_df = spark \
    .read \
    .option("header", "true") \
    .option("inferSchema", "true") \
    .csv("/mnt/datalake/yellow_tripdata_2018-12.csv")
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
display(yellow_taxi_trip_df.describe("passenger_count", "trip_distance"))
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>summary</th><th>passenger_count</th><th>trip_distance</th></tr></thead><tbody><tr><td>count</td><td>8173231</td><td>8173231</td></tr><tr><td>mean</td><td>1.5964102813195908</td><td>2.8926264215460553</td></tr><tr><td>stddev</td><td>1.233920232393633</td><td>3.764338945224816</td></tr><tr><td>min</td><td>0</td><td>0.0</td></tr><tr><td>max</td><td>9</td><td>602.3</td></tr></tbody></table></div>

# %%
filtered_yellow_taxi_trips = yellow_taxi_trip_df.where((yellow_taxi_trip_df['trip_distance'] > 0) & (yellow_taxi_trip_df['passenger_count'] > 0))
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
display(filtered_yellow_taxi_trips.describe("passenger_count", "trip_distance"))
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>summary</th><th>passenger_count</th><th>trip_distance</th></tr></thead><tbody><tr><td>count</td><td>7997713</td><td>7997713</td></tr><tr><td>mean</td><td>1.6208786186751138</td><td>2.9159603939275436</td></tr><tr><td>stddev</td><td>1.229214263122363</td><td>3.771235678655414</td></tr><tr><td>min</td><td>1</td><td>0.01</td></tr><tr><td>max</td><td>9</td><td>602.3</td></tr></tbody></table></div>

# %%
print('before = ', filtered_yellow_taxi_trips.count())
filtered_yellow_taxi_trips = filtered_yellow_taxi_trips.dropna(subset=("PULocationID", "DOLocationID"))
print('after', filtered_yellow_taxi_trips.count())
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">before =  7997713
# after 7997713
# </div>

# %%
default_values_dict = {
  "payment_type": 5,
  "RateCodeId": 1
}

filtered_yellow_taxi_trips = filtered_yellow_taxi_trips.na.fill(default_values_dict)
#filtered_yellow_taxi_trips = filtered_yellow_taxi_trips.na.fill(value=0, subset=("PULocationID"))
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
print('before = ', filtered_yellow_taxi_trips.count())
filtered_yellow_taxi_trips = filtered_yellow_taxi_trips.drop_duplicates()
print('after', filtered_yellow_taxi_trips.count())
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">before =  7997713
# after 7997713
# </div>

# %%
print('before = ', filtered_yellow_taxi_trips.count())
filtered_yellow_taxi_trips = filtered_yellow_taxi_trips \
                              .where("tpep_pickup_datetime >= '2018-12-01' AND tpep_dropoff_datetime < '2019-01-01'")

print('after', filtered_yellow_taxi_trips.count())
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">before =  7997713
# after 7995244
# </div>

# %%
green_taxi_trip_df = spark \
    .read \
    .option("header", "true") \
    .option("inferSchema", "true") \
    .option("delimiter", "\t") \
    .csv("/mnt/datalake/green_tripdata_2018-12.csv")
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
display(green_taxi_trip_df.describe())
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>summary</th><th>VendorID	lpep_pickup_datetime	lpep_dropoff_datetime	store_and_fwd_flag	RatecodeID	PULocationID	DOLocationID	passenger_count	trip_distance	fare_amount	extra	mta_tax	tip_amount	tolls_amount	ehail_fee	improvement_surcharge	total_amount	payment_type	trip_type</th></tr></thead><tbody><tr><td>count</td><td>685373</td></tr><tr><td>mean</td><td>null</td></tr><tr><td>stddev</td><td>null</td></tr><tr><td>min</td><td>1	2018-12-01 00:00:27	2018-12-01 00:18:15	N	1	106	4	1	6.00	19	0.5	0.5	3.05	0	""	0.3	23.35	1	1</td></tr><tr><td>max</td><td>2	2019-03-11 22:23:32	2019-03-11 22:34:23	N	1	182	242	1	1.87	9	0	0.5	0	0	""	0.3	9.8	1	1</td></tr></tbody></table></div>

# %% [markdown]
# ###All the above cleanup oprations in a single step (Yellow taxi)

# %%
from pyspark.sql.functions import year, month, dayofmonth, unix_timestamp, round, when, col

yellow_taxi_trip_df = spark \
    .read \
    .option("header", "true") \
    .option("inferSchema", "true") \
    .csv("/mnt/datalake/yellow_tripdata_2018-12.csv")

default_values_dict = {
  "payment_type": 5,
  "RateCodeId": 1
}

print('before = ', yellow_taxi_trip_df.count())

filtered_yellow_taxi_trips = yellow_taxi_trip_df.where((yellow_taxi_trip_df['trip_distance'] > 0) & (yellow_taxi_trip_df['passenger_count'] > 0)) \
                                                .dropna(subset=("PULocationID", "DOLocationID")) \
                                                .na.fill(default_values_dict) \
                                                .drop_duplicates() \
                                                .where("tpep_pickup_datetime >= '2018-12-01' AND tpep_dropoff_datetime < '2019-01-01'")

print('after', filtered_yellow_taxi_trips.count())
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">before =  8173231
# after 7995244
# </div>

# %% [markdown]
# ###All transformation oprations in a single step (Yellow taxi)

# %%
filtered_yellow_taxi_trips = filtered_yellow_taxi_trips \
                             .select( \
                              col('VendorID').alias('vendor_id'), \
                              col('tpep_pickup_datetime').alias('pickup_time'), \
                              col('tpep_dropoff_datetime').alias('dropoff_time'), \
                              col('trip_distance'), \
                              col('PULocationID').alias('pickup_loc'), \
                              col('DOLocationID').alias('dropoff_loc'), \
                              col('RatecodeID').alias('rate_code_id'), \
                              col('total_amount'), \
                              col('payment_type') \
                              ) \
                              \
                             .withColumn("trip_year", year('pickup_time')) \
                             .withColumn("trip_month", month('pickup_time')) \
                             .withColumn("trip_day", dayofmonth('pickup_time')) \
                              \
                              .withColumn("trip_duration", \
                                          round((unix_timestamp('dropoff_time') - unix_timestamp('pickup_time')) / 60) \
                                         ) \
                              \
                              .withColumn( \
                                          'trip_type', \
                                                      when(
                                                      col('rate_code_id') == 6, 'shared_trip'
                                                      )\
                                                      .when(
                                                      col('rate_code_id') == 1000, 'shared_trip' # There is no rate_code_id value of 1000. Have included for "switch case" example
                                                      )
                                                      .otherwise('solo_trip')
                                         ) \
                              .drop('rate_code_id')
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
'''
filtered_yellow_taxi_trips = filtered_yellow_taxi_trips \
                .withColumn("trip_year", year('pickup_time')) \
                .withColumn("trip_month", month('pickup_time')) \
                .withColumn("trip_day", dayofmonth('pickup_time')) \
                \
                .withColumn("trip_duration", \
                            round(unix_timestamp('pickup_time') - unix_timestamp('dropoff_time')) / 60 \
                           )

filtered_yellow_taxi_trips = filtered_yellow_taxi_trips.withColumn( \
                                                                  'trip_type', \
                                                                  when(
                                                                  col('SR_Flag') == 1, 'shared_trip'
                                                                  )\
                                                                  .when(
                                                                  col('SR_Flag') == 2, 'shared_trip'
                                                                  )
                                                                  .otherwise('solo_trip')


'''
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %% [markdown]
# ###All the above cleanup oprations in a single step (green taxi)

# %%
# Note the "delimiter" option. In green taxi csv, commas are not the seperators. <tab> has been used as a seperator
green_taxi_trip_df = spark \
    .read \
    .option("header", "true") \
    .option("inferSchema", "true") \
    .option("delimiter", "\t") \
    .csv("/mnt/datalake/green_tripdata_2018-12.csv")

default_values_dict = {
  "payment_type": 5,
  "RateCodeId": 1
}

#print('before = ', green_taxi_trip_df.count())

filtered_green_taxi_trips = green_taxi_trip_df.where((green_taxi_trip_df['trip_distance'] > 0) & (green_taxi_trip_df['passenger_count'] > 0)) \
                                                .dropna(subset=("PULocationID", "DOLocationID")) \
                                                .na.fill(default_values_dict) \
                                                .drop_duplicates() \
                                                .where("lpep_pickup_datetime >= '2018-12-01' AND lpep_dropoff_datetime < '2019-01-01'")

#print('after', filtered_green_taxi_trips.count())
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %% [markdown]
# ###All transformation oprations in a single step (green taxi)

# %%
filtered_green_taxi_trips = filtered_green_taxi_trips \
                             .select( \
                              col('VendorID').alias('vendor_id'), \
                              col('lpep_pickup_datetime').alias('pickup_time'), \
                              col('lpep_dropoff_datetime').alias('dropoff_time'), \
                              col('trip_distance'), \
                              col('PULocationID').alias('pickup_loc'), \
                              col('DOLocationID').alias('dropoff_loc'), \
                              col('RatecodeID').alias('rate_code_id'), \
                              col('total_amount'), \
                              col('payment_type') \
                              ) \
                              \
                             .withColumn("trip_year", year('pickup_time')) \
                             .withColumn("trip_month", month('pickup_time')) \
                             .withColumn("trip_day", dayofmonth('pickup_time')) \
                              \
                              .withColumn("trip_duration", \
                                          round((unix_timestamp('dropoff_time') - unix_timestamp('pickup_time')) / 60) \
                                         ) \
                              \
                              .withColumn( \
                                          'trip_type', \
                                                      when(
                                                      col('rate_code_id') == 6, 'shared_trip'
                                                      )\
                                                      .when(
                                                      col('rate_code_id') == 1000, 'shared_trip' # There is no rate_code_id value of 1000. Have included for "switch case" example
                                                      )
                                                      .otherwise('solo_trip')
                                         ) \
                              .drop('rate_code_id')
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
filtered_yellow_taxi_trips.createOrReplaceGlobalTempView('fact_yellow_taxi_trip_data')
filtered_green_taxi_trips.createOrReplaceGlobalTempView('fact_green_taxi_trip_data')
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
display(filtered_yellow_taxi_trips)

# %%
display(filtered_green_taxi_trips)

# %%
spark.conf.get("spark.sql.shuffle.partitions")

# If you partition the table based on a particular column, most likely all the rows that belong a particular "column value" will be stored as individual partitions in hdfs
# So, if there is a column that you will be querying on frequently, you should partition the table by that col
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[31]: &#39;200&#39;</div>

# %%
filtered_green_taxi_trips.write \
                              .option('header', 'true') \
                              .option('dateFormat', 'yyyy-MM-dd HH:mm:ss.S') \
                              .mode('overwrite') \
                              .csv('/mnt/datalake/dimensional_model/facts/green_taxi_fact.csv')
# other options for mode are 'append', 'overwrite', 'ignore' and 'error' https://kontext.tech/column/spark/357/save-dataframe-as-csv-file-in-spark
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
filtered_green_taxi_trips.write \
                          .option('header', 'true') \
                          .option('dateFormat', 'yyyy-MM-dd HH:mm:ss.S') \
                          .mode('ignore') \
                          .parquet('/mnt/datalake/dimensional_model/facts/green_taxi_fact.parquet')
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
green_taxi_trips_csv_df = spark.read \
                                .option('header', 'true') \
                                .csv('/mnt/datalake/dimensional_model/facts/green_taxi_fact.csv')

print(green_taxi_trips_csv_df.select('pickup_loc', 'dropoff_loc').distinct().count())

# you cannot use display() instead of print here because display can only be used to print spark dataframe objects
# since the .count() outputs a number, we used print
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">25052
# </div>

# %%
green_taxi_trips_parquet_df = spark.read \
                                .parquet('/mnt/datalake/dimensional_model/facts/green_taxi_fact.parquet')

print(green_taxi_trips_parquet_df.select('pickup_loc', 'dropoff_loc').distinct().count())

# reading data from parquet is much faster. Writing data to parquet is slower because the schema is stored in parquet file.
# If more read operations are anticipated on a file, parquet format is better and vice versa
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">25052
# </div>

# %%
# %sql

create database if not exists taxi_service_warehouse;
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr></tr></thead><tbody></tbody></table></div>

# %%
green_taxi_trip_df.write \
                  .mode('overwrite') \
                  .saveAsTable("taxi_service_warehouse.green_taxi_trips_managed")
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
# %sql

select * from taxi_service_warehouse.green_taxi_trips_managed limit 10
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>VendorID</th><th>lpep_pickup_datetime</th><th>lpep_dropoff_datetime</th><th>store_and_fwd_flag</th><th>RatecodeID</th><th>PULocationID</th><th>DOLocationID</th><th>passenger_count</th><th>trip_distance</th><th>fare_amount</th><th>extra</th><th>mta_tax</th><th>tip_amount</th><th>tolls_amount</th><th>ehail_fee</th><th>improvement_surcharge</th><th>total_amount</th><th>payment_type</th><th>trip_type</th></tr></thead><tbody><tr><td>2</td><td>2018-12-16 13:35:23</td><td>2018-12-16 13:54:54</td><td>N</td><td>5</td><td>77</td><td>91</td><td>1</td><td>4.02</td><td>15.0</td><td>0.0</td><td>0.5</td><td>0.0</td><td>0.0</td><td>null</td><td>0.0</td><td>15.5</td><td>1</td><td>2</td></tr><tr><td>2</td><td>2018-12-16 13:42:05</td><td>2018-12-16 13:45:16</td><td>N</td><td>1</td><td>74</td><td>42</td><td>1</td><td>0.79</td><td>4.5</td><td>0.0</td><td>0.5</td><td>0.0</td><td>0.0</td><td>null</td><td>0.3</td><td>5.3</td><td>2</td><td>1</td></tr><tr><td>2</td><td>2018-12-16 13:17:51</td><td>2018-12-16 13:30:00</td><td>N</td><td>1</td><td>82</td><td>95</td><td>2</td><td>1.64</td><td>9.5</td><td>0.0</td><td>0.5</td><td>2.06</td><td>0.0</td><td>null</td><td>0.3</td><td>12.36</td><td>1</td><td>1</td></tr><tr><td>2</td><td>2018-12-16 13:40:11</td><td>2018-12-16 13:51:36</td><td>N</td><td>1</td><td>82</td><td>83</td><td>2</td><td>3.35</td><td>13.0</td><td>0.0</td><td>0.5</td><td>0.0</td><td>0.0</td><td>null</td><td>0.3</td><td>13.8</td><td>2</td><td>1</td></tr><tr><td>2</td><td>2018-12-16 13:55:52</td><td>2018-12-16 14:20:24</td><td>N</td><td>1</td><td>260</td><td>170</td><td>2</td><td>5.23</td><td>19.5</td><td>0.0</td><td>0.5</td><td>0.0</td><td>0.0</td><td>null</td><td>0.3</td><td>20.3</td><td>2</td><td>1</td></tr><tr><td>2</td><td>2018-12-16 13:06:06</td><td>2018-12-16 13:14:52</td><td>N</td><td>1</td><td>74</td><td>236</td><td>3</td><td>1.92</td><td>8.5</td><td>0.0</td><td>0.5</td><td>2.5</td><td>0.0</td><td>null</td><td>0.3</td><td>11.8</td><td>1</td><td>1</td></tr><tr><td>2</td><td>2018-12-16 13:25:53</td><td>2018-12-16 13:31:16</td><td>N</td><td>1</td><td>41</td><td>42</td><td>3</td><td>0.95</td><td>6.0</td><td>0.0</td><td>0.5</td><td>0.0</td><td>0.0</td><td>null</td><td>0.3</td><td>6.8</td><td>2</td><td>1</td></tr><tr><td>2</td><td>2018-12-16 13:35:59</td><td>2018-12-16 13:40:12</td><td>N</td><td>1</td><td>42</td><td>74</td><td>3</td><td>0.78</td><td>5.0</td><td>0.0</td><td>0.5</td><td>0.0</td><td>0.0</td><td>null</td><td>0.3</td><td>5.8</td><td>1</td><td>1</td></tr><tr><td>2</td><td>2018-12-16 13:02:59</td><td>2018-12-16 13:26:31</td><td>N</td><td>1</td><td>226</td><td>196</td><td>1</td><td>3.9</td><td>17.5</td><td>0.0</td><td>0.5</td><td>0.0</td><td>0.0</td><td>null</td><td>0.3</td><td>18.3</td><td>1</td><td>1</td></tr><tr><td>2</td><td>2018-12-16 13:50:57</td><td>2018-12-16 15:03:04</td><td>N</td><td>5</td><td>95</td><td>186</td><td>1</td><td>10.13</td><td>30.82</td><td>0.0</td><td>0.5</td><td>0.0</td><td>5.76</td><td>null</td><td>0.0</td><td>37.08</td><td>1</td><td>2</td></tr></tbody></table></div>

# %%
# %sql

describe taxi_service_warehouse.green_taxi_trips_managed;
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>col_name</th><th>data_type</th><th>comment</th></tr></thead><tbody><tr><td>VendorID</td><td>int</td><td>null</td></tr><tr><td>lpep_pickup_datetime</td><td>string</td><td>null</td></tr><tr><td>lpep_dropoff_datetime</td><td>string</td><td>null</td></tr><tr><td>store_and_fwd_flag</td><td>string</td><td>null</td></tr><tr><td>RatecodeID</td><td>int</td><td>null</td></tr><tr><td>PULocationID</td><td>int</td><td>null</td></tr><tr><td>DOLocationID</td><td>int</td><td>null</td></tr><tr><td>passenger_count</td><td>int</td><td>null</td></tr><tr><td>trip_distance</td><td>double</td><td>null</td></tr><tr><td>fare_amount</td><td>double</td><td>null</td></tr><tr><td>extra</td><td>double</td><td>null</td></tr><tr><td>mta_tax</td><td>double</td><td>null</td></tr><tr><td>tip_amount</td><td>double</td><td>null</td></tr><tr><td>tolls_amount</td><td>double</td><td>null</td></tr><tr><td>ehail_fee</td><td>string</td><td>null</td></tr><tr><td>improvement_surcharge</td><td>double</td><td>null</td></tr><tr><td>total_amount</td><td>double</td><td>null</td></tr><tr><td>payment_type</td><td>int</td><td>null</td></tr><tr><td>trip_type</td><td>int</td><td>null</td></tr></tbody></table></div>

# %%
# %sql

describe extended taxi_service_warehouse.green_taxi_trips_managed;
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>col_name</th><th>data_type</th><th>comment</th></tr></thead><tbody><tr><td>VendorID</td><td>int</td><td>null</td></tr><tr><td>lpep_pickup_datetime</td><td>string</td><td>null</td></tr><tr><td>lpep_dropoff_datetime</td><td>string</td><td>null</td></tr><tr><td>store_and_fwd_flag</td><td>string</td><td>null</td></tr><tr><td>RatecodeID</td><td>int</td><td>null</td></tr><tr><td>PULocationID</td><td>int</td><td>null</td></tr><tr><td>DOLocationID</td><td>int</td><td>null</td></tr><tr><td>passenger_count</td><td>int</td><td>null</td></tr><tr><td>trip_distance</td><td>double</td><td>null</td></tr><tr><td>fare_amount</td><td>double</td><td>null</td></tr><tr><td>extra</td><td>double</td><td>null</td></tr><tr><td>mta_tax</td><td>double</td><td>null</td></tr><tr><td>tip_amount</td><td>double</td><td>null</td></tr><tr><td>tolls_amount</td><td>double</td><td>null</td></tr><tr><td>ehail_fee</td><td>string</td><td>null</td></tr><tr><td>improvement_surcharge</td><td>double</td><td>null</td></tr><tr><td>total_amount</td><td>double</td><td>null</td></tr><tr><td>payment_type</td><td>int</td><td>null</td></tr><tr><td>trip_type</td><td>int</td><td>null</td></tr><tr><td></td><td></td><td></td></tr><tr><td># Detailed Table Information</td><td></td><td></td></tr><tr><td>Database</td><td>taxi_service_warehouse</td><td></td></tr><tr><td>Table</td><td>green_taxi_trips_managed</td><td></td></tr><tr><td>Owner</td><td>root</td><td></td></tr><tr><td>Created Time</td><td>Sat Jan 16 03:24:21 UTC 2021</td><td></td></tr><tr><td>Last Access</td><td>UNKNOWN</td><td></td></tr><tr><td>Created By</td><td>Spark 3.0.1</td><td></td></tr><tr><td>Type</td><td>MANAGED</td><td></td></tr><tr><td>Provider</td><td>parquet</td><td></td></tr><tr><td>Location</td><td>dbfs:/user/hive/warehouse/taxi_service_warehouse.db/green_taxi_trips_managed</td><td></td></tr><tr><td>Serde Library</td><td>org.apache.hadoop.hive.ql.io.parquet.serde.ParquetHiveSerDe</td><td></td></tr><tr><td>InputFormat</td><td>org.apache.hadoop.hive.ql.io.parquet.MapredParquetInputFormat</td><td></td></tr><tr><td>OutputFormat</td><td>org.apache.hadoop.hive.ql.io.parquet.MapredParquetOutputFormat</td><td></td></tr></tbody></table></div>

# %%
# %sql

drop table taxi_service_warehouse.green_taxi_trips_managed;
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr></tr></thead><tbody></tbody></table></div>

# %%
green_taxi_trip_df.write \
                  .mode('overwrite') \
                  .option('path', '/mnt/datalake/dimensional_model/facts/green_taxi_fact.parquet') \
                  .saveAsTable('taxi_service_warehouse.fact_green_taxi_trips_data')
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
# %sql

describe extended taxi_service_warehouse.fact_green_taxi_trips_data
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>col_name</th><th>data_type</th><th>comment</th></tr></thead><tbody><tr><td>VendorID</td><td>int</td><td>null</td></tr><tr><td>lpep_pickup_datetime</td><td>string</td><td>null</td></tr><tr><td>lpep_dropoff_datetime</td><td>string</td><td>null</td></tr><tr><td>store_and_fwd_flag</td><td>string</td><td>null</td></tr><tr><td>RatecodeID</td><td>int</td><td>null</td></tr><tr><td>PULocationID</td><td>int</td><td>null</td></tr><tr><td>DOLocationID</td><td>int</td><td>null</td></tr><tr><td>passenger_count</td><td>int</td><td>null</td></tr><tr><td>trip_distance</td><td>double</td><td>null</td></tr><tr><td>fare_amount</td><td>double</td><td>null</td></tr><tr><td>extra</td><td>double</td><td>null</td></tr><tr><td>mta_tax</td><td>double</td><td>null</td></tr><tr><td>tip_amount</td><td>double</td><td>null</td></tr><tr><td>tolls_amount</td><td>double</td><td>null</td></tr><tr><td>ehail_fee</td><td>string</td><td>null</td></tr><tr><td>improvement_surcharge</td><td>double</td><td>null</td></tr><tr><td>total_amount</td><td>double</td><td>null</td></tr><tr><td>payment_type</td><td>int</td><td>null</td></tr><tr><td>trip_type</td><td>int</td><td>null</td></tr><tr><td></td><td></td><td></td></tr><tr><td># Detailed Table Information</td><td></td><td></td></tr><tr><td>Database</td><td>taxi_service_warehouse</td><td></td></tr><tr><td>Table</td><td>fact_green_taxi_trips_data</td><td></td></tr><tr><td>Owner</td><td>root</td><td></td></tr><tr><td>Created Time</td><td>Sat Jan 16 04:02:56 UTC 2021</td><td></td></tr><tr><td>Last Access</td><td>UNKNOWN</td><td></td></tr><tr><td>Created By</td><td>Spark 3.0.1</td><td></td></tr><tr><td>Type</td><td>EXTERNAL</td><td></td></tr><tr><td>Provider</td><td>parquet</td><td></td></tr><tr><td>Location</td><td>dbfs:/mnt/datalake/dimensional_model/facts/green_taxi_fact.parquet</td><td></td></tr><tr><td>Serde Library</td><td>org.apache.hadoop.hive.ql.io.parquet.serde.ParquetHiveSerDe</td><td></td></tr><tr><td>InputFormat</td><td>org.apache.hadoop.hive.ql.io.parquet.MapredParquetInputFormat</td><td></td></tr><tr><td>OutputFormat</td><td>org.apache.hadoop.hive.ql.io.parquet.MapredParquetOutputFormat</td><td></td></tr></tbody></table></div>

# %%
# %sql

drop table taxi_service_warehouse.fact_green_taxi_trips_data
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr></tr></thead><tbody></tbody></table></div>

# %%
# %sql
/* DO NOT HAVE <SPACE> BETWEEN % and SQL. Magic commands (commands that start with %) should not have space between characters */
CREATE TABLE IF NOT EXISTS taxi_service_warehouse.fact_green_taxi_trips_data
    USING parquet
    OPTIONS 
    (
        path "/mnt/datalake/dimensional_model/facts/green_taxi_fact.parquet"
    )
    
/* Another way of creating a table
CREATE TABLE IF NOT EXISTS taxi_service_warehouse.fact_green_taxi_trips_data
    USING parquet
    location "/mnt/datalake/dimensional_model/facts/green_taxi_fact.parquet"
*/
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr></tr></thead><tbody></tbody></table></div>
